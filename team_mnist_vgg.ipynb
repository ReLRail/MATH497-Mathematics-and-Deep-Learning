# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jul 19 17:45:06 2019

@author: Team 3
"""

import torch
import torch.nn as nn
import math
import torchvision.transforms as transforms
import torchvision as tv
from torch.utils.data import DataLoader
CUDA_VISIBLE_DEVICES=(7)
# Define if GPU be used or not
model_path = './model_pth/vgg16_bn-6c64b313.pth'
BATCH_SIZE = 64
LR = 0.001
EPOCH = 10

class VGG(nn.Module):
    def __init__(self, features, num_classes=10): #Algorithm
        super(VGG, self).__init__()
        # Module
        self.features = features
        self.classifier = nn.Sequential( #classifier module
            #fc6
            nn.Linear(256*1*1, 1024),
            nn.ReLU(),
            nn.Dropout(),
 
            #fc7
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(),
 
            #fc8
            nn.Linear(512, num_classes))
        # initialize
        self._initialize_weights()
 
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x
 
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()
 
#cfg = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M']

cfg = {
    'A': [32, 32, 'M', 64, 64, 'M', 128, 128, 128, 'M', 128, 128, 128, 'M', 256, 256, 256, 'M'],
    'B': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
} 

# layers
def make_layers(cfg, batch_norm=False):
    layers = []
    in_channels = 1
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            # cfg for conv
            conv2d = nn.Conv2d(in_channels, v, 3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers) # response the sequential 
 
def vgg16(**kwargs):
    model = VGG(make_layers(cfg['A'], batch_norm=True), **kwargs)
    #model.load_state_dict(torch.load(model_path))
    return model
 
def getData(): 
    transform = transforms.Compose([
        transforms.RandomResizedCrop(48),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.1307],
                             std=[0.3081])])
    trainset = tv.datasets.MNIST(
        root='mnist/',  #dataset saving address
        train = True , #True=train，Flase=test
        transform = transform,# tv.transforms.ToTensor(),  #interval（0,1）
        download=True,
        )
    testset = tv.datasets.MNIST(
        root = 'mnist/', #dataset saving address
        train = False, #True=train，False=test
        transform = transform,#tv.transforms.ToTensor(),
        download = True,
        )
    #trainset = tv.datasets.CIFAR10(root='./root/', train=True, transform=transform, download=True)
    #testset = tv.datasets.CIFAR10(root='./root/', train=False, transform=transform, download=True)
 
    train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
    test_loader = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)
    return train_loader, test_loader
 
def train():
    trainset_loader, testset_loader = getData()
    net = vgg16().cuda()
    net.train()
 
    # Loss and Optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=LR)
    # Train the model
    losses = []
    acces = []
    train_loss = 0
    for epoch in range(EPOCH):
        for step, (inputs,labels) in enumerate(trainset_loader):
            inputs, labels = inputs.cuda(), labels.cuda()
            inputs = inputs.cuda()
            labels = labels.cuda()
            output = net(inputs)
            loss = criterion(output, labels)
            optimizer.zero_grad() 
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            if step % 100 ==0:
                print('Epoch:', epoch, '|Step:', step,  
                  '|train loss:%.4f'%loss.data.item())
                acc = test(net, testset_loader)
                print('Epoch', epoch, '|step ', step, 'loss: %.4f' %loss.item(), 'test accuracy:%.4f' %acc)
        print('Finished Training')
        acc = test(net, testset_loader)
        print('Epoch', epoch, '|step ', step, 'loss: %.4f' %loss.item(), 'test accuracy:%.4f' %acc)
        losses.append(train_loss / len(trainset_loader))
        
    return net
 
def test(net, testdata):
    correct, total = .0, .0
    for inputs, labels in testdata:
        net.eval()
        inputs, labels = inputs.cuda(), labels.cuda()
        inputs = inputs.cuda()
        labels = labels.cuda()
        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum()
    #net.train()
    return float(correct) / total
 
if __name__ == '__main__':
    net = train()
# Out:
# Epoch: 0 |Step: 0 |train loss:2.3018
# Epoch 0 |step  0 loss: 2.3018 test accuracy:0.0916
# Epoch: 0 |Step: 100 |train loss:2.3034
# Epoch 0 |step  100 loss: 2.3034 test accuracy:0.1135
# Epoch: 0 |Step: 200 |train loss:2.1854
# Epoch 0 |step  200 loss: 2.1854 test accuracy:0.2417
# Epoch: 0 |Step: 300 |train loss:1.9398
# Epoch 0 |step  300 loss: 1.9398 test accuracy:0.3019
# Epoch: 0 |Step: 400 |train loss:1.5878
# Epoch 0 |step  400 loss: 1.5878 test accuracy:0.3459
# Epoch: 0 |Step: 500 |train loss:1.6365
# Epoch 0 |step  500 loss: 1.6365 test accuracy:0.4341
# Epoch: 0 |Step: 600 |train loss:1.5114
# Epoch 0 |step  600 loss: 1.5114 test accuracy:0.4693
# Epoch: 0 |Step: 700 |train loss:1.5864
# Epoch 0 |step  700 loss: 1.5864 test accuracy:0.5071
# Epoch: 0 |Step: 800 |train loss:1.1220
# Epoch 0 |step  800 loss: 1.1220 test accuracy:0.5845
# Epoch: 0 |Step: 900 |train loss:1.0754
# Epoch 0 |step  900 loss: 1.0754 test accuracy:0.6060
# Finished Training
# Epoch 0 |step  937 loss: 0.9073 test accuracy:0.6108
# Epoch: 1 |Step: 0 |train loss:1.3939
# Epoch 1 |step  0 loss: 1.3939 test accuracy:0.6238
# Epoch: 1 |Step: 100 |train loss:1.2003
# Epoch 1 |step  100 loss: 1.2003 test accuracy:0.6461
# Epoch: 1 |Step: 200 |train loss:0.9825
# Epoch 1 |step  200 loss: 0.9825 test accuracy:0.6489
# Epoch: 1 |Step: 300 |train loss:0.7380
# Epoch 1 |step  300 loss: 0.7380 test accuracy:0.6943
# Epoch: 1 |Step: 400 |train loss:1.1142
# Epoch 1 |step  400 loss: 1.1142 test accuracy:0.7118
# Epoch: 1 |Step: 500 |train loss:1.0758
# Epoch 1 |step  500 loss: 1.0758 test accuracy:0.7285
# Epoch: 1 |Step: 600 |train loss:0.9955
# Epoch 1 |step  600 loss: 0.9955 test accuracy:0.7415
# Epoch: 1 |Step: 700 |train loss:0.9055
# Epoch 1 |step  700 loss: 0.9055 test accuracy:0.7453
# Epoch: 1 |Step: 800 |train loss:0.8325
# Epoch 1 |step  800 loss: 0.8325 test accuracy:0.7648
# Epoch: 1 |Step: 900 |train loss:0.7370
# Epoch 1 |step  900 loss: 0.7370 test accuracy:0.7751
# Finished Training
# Epoch 1 |step  937 loss: 0.7030 test accuracy:0.7718
# Epoch: 2 |Step: 0 |train loss:0.5307
# Epoch 2 |step  0 loss: 0.5307 test accuracy:0.7659
# Epoch: 2 |Step: 100 |train loss:0.6831
# Epoch 2 |step  100 loss: 0.6831 test accuracy:0.7859
# Epoch: 2 |Step: 200 |train loss:0.9843
# Epoch 2 |step  200 loss: 0.9843 test accuracy:0.7834
# Epoch: 2 |Step: 300 |train loss:0.8047
# Epoch 2 |step  300 loss: 0.8047 test accuracy:0.7916
# Epoch: 2 |Step: 400 |train loss:0.6917
# Epoch 2 |step  400 loss: 0.6917 test accuracy:0.7951
# Epoch: 2 |Step: 500 |train loss:0.6600
# Epoch 2 |step  500 loss: 0.6600 test accuracy:0.7967
# Epoch: 2 |Step: 600 |train loss:0.6661
# Epoch 2 |step  600 loss: 0.6661 test accuracy:0.8088
# Epoch: 2 |Step: 700 |train loss:0.7267
# Epoch 2 |step  700 loss: 0.7267 test accuracy:0.7971
# Epoch: 2 |Step: 800 |train loss:0.6412
# Epoch 2 |step  800 loss: 0.6412 test accuracy:0.8195
# Epoch: 2 |Step: 900 |train loss:0.5050
# Epoch 2 |step  900 loss: 0.5050 test accuracy:0.8116
# Finished Training
# Epoch 2 |step  937 loss: 0.7192 test accuracy:0.8064
# Epoch: 3 |Step: 0 |train loss:0.4241
# Epoch 3 |step  0 loss: 0.4241 test accuracy:0.8072
# Epoch: 3 |Step: 100 |train loss:0.5291
# Epoch 3 |step  100 loss: 0.5291 test accuracy:0.8211
# Epoch: 3 |Step: 200 |train loss:0.7398
# Epoch 3 |step  200 loss: 0.7398 test accuracy:0.8169
# Epoch: 3 |Step: 300 |train loss:0.5023
# Epoch 3 |step  300 loss: 0.5023 test accuracy:0.8107
# Epoch: 3 |Step: 400 |train loss:0.8946
# Epoch 3 |step  400 loss: 0.8946 test accuracy:0.8143
# Epoch: 3 |Step: 500 |train loss:0.7322
# Epoch 3 |step  500 loss: 0.7322 test accuracy:0.8224
# Epoch: 3 |Step: 600 |train loss:0.5413
# Epoch 3 |step  600 loss: 0.5413 test accuracy:0.8354
# Epoch: 3 |Step: 700 |train loss:0.6375
# Epoch 3 |step  700 loss: 0.6375 test accuracy:0.8233
# Epoch: 3 |Step: 800 |train loss:0.4891
# Epoch 3 |step  800 loss: 0.4891 test accuracy:0.8211
# Epoch: 3 |Step: 900 |train loss:0.5366
# Epoch 3 |step  900 loss: 0.5366 test accuracy:0.8210
# Finished Training
# Epoch 3 |step  937 loss: 0.6771 test accuracy:0.8246
# Epoch: 4 |Step: 0 |train loss:0.4077
# Epoch 4 |step  0 loss: 0.4077 test accuracy:0.8294
# Epoch: 4 |Step: 100 |train loss:0.3412
# Epoch 4 |step  100 loss: 0.3412 test accuracy:0.8191
# Epoch: 4 |Step: 200 |train loss:0.7090
# Epoch 4 |step  200 loss: 0.7090 test accuracy:0.8399
# Epoch: 4 |Step: 300 |train loss:0.5766
# Epoch 4 |step  300 loss: 0.5766 test accuracy:0.8322
# Epoch: 4 |Step: 400 |train loss:0.6096
# Epoch 4 |step  400 loss: 0.6096 test accuracy:0.8280
# Epoch: 4 |Step: 500 |train loss:0.5644
# Epoch 4 |step  500 loss: 0.5644 test accuracy:0.8324
# Epoch: 4 |Step: 600 |train loss:0.4095
# Epoch 4 |step  600 loss: 0.4095 test accuracy:0.8378
# Epoch: 4 |Step: 700 |train loss:0.3564
# Epoch 4 |step  700 loss: 0.3564 test accuracy:0.8286
# Epoch: 4 |Step: 800 |train loss:0.3072
# Epoch 4 |step  800 loss: 0.3072 test accuracy:0.8310
# Epoch: 4 |Step: 900 |train loss:0.2945
# Epoch 4 |step  900 loss: 0.2945 test accuracy:0.8455
# Finished Training
# Epoch 4 |step  937 loss: 0.4889 test accuracy:0.8431
# Epoch: 5 |Step: 0 |train loss:0.6483
# Epoch 5 |step  0 loss: 0.6483 test accuracy:0.8395
# Epoch: 5 |Step: 100 |train loss:0.4776
# Epoch 5 |step  100 loss: 0.4776 test accuracy:0.8473
# Epoch: 5 |Step: 200 |train loss:0.5905
# Epoch 5 |step  200 loss: 0.5905 test accuracy:0.8396
# Epoch: 5 |Step: 300 |train loss:0.4399
# Epoch 5 |step  300 loss: 0.4399 test accuracy:0.8425
# Epoch: 5 |Step: 400 |train loss:0.7073
# Epoch 5 |step  400 loss: 0.7073 test accuracy:0.8468
# Epoch: 5 |Step: 500 |train loss:0.5403
# Epoch 5 |step  500 loss: 0.5403 test accuracy:0.8381
# Epoch: 5 |Step: 600 |train loss:0.6116
# Epoch 5 |step  600 loss: 0.6116 test accuracy:0.8423
# Epoch: 5 |Step: 700 |train loss:0.4016
# Epoch 5 |step  700 loss: 0.4016 test accuracy:0.8472
# Epoch: 5 |Step: 800 |train loss:0.6185
# Epoch 5 |step  800 loss: 0.6185 test accuracy:0.8363
# Epoch: 5 |Step: 900 |train loss:0.6143
# Epoch 5 |step  900 loss: 0.6143 test accuracy:0.8464
# Finished Training
# Epoch 5 |step  937 loss: 0.8903 test accuracy:0.8501
# Epoch: 6 |Step: 0 |train loss:0.4518
# Epoch 6 |step  0 loss: 0.4518 test accuracy:0.8394
# Epoch: 6 |Step: 100 |train loss:0.4116
# Epoch 6 |step  100 loss: 0.4116 test accuracy:0.8388
# Epoch: 6 |Step: 200 |train loss:0.5277
# Epoch 6 |step  200 loss: 0.5277 test accuracy:0.8459
# Epoch: 6 |Step: 300 |train loss:0.3989
# Epoch 6 |step  300 loss: 0.3989 test accuracy:0.8445
# Epoch: 6 |Step: 400 |train loss:0.3377
# Epoch 6 |step  400 loss: 0.3377 test accuracy:0.8447
# Epoch: 6 |Step: 500 |train loss:0.4912
# Epoch 6 |step  500 loss: 0.4912 test accuracy:0.8461
# Epoch: 6 |Step: 600 |train loss:0.4805
# Epoch 6 |step  600 loss: 0.4805 test accuracy:0.8412
# Epoch: 6 |Step: 700 |train loss:0.2641
# Epoch 6 |step  700 loss: 0.2641 test accuracy:0.8505
# Epoch: 6 |Step: 800 |train loss:0.6134
# Epoch 6 |step  800 loss: 0.6134 test accuracy:0.8566
# Epoch: 6 |Step: 900 |train loss:0.4536
# Epoch 6 |step  900 loss: 0.4536 test accuracy:0.8546
# Finished Training
# Epoch 6 |step  937 loss: 0.4166 test accuracy:0.8438
# Epoch: 7 |Step: 0 |train loss:0.5287
# Epoch 7 |step  0 loss: 0.5287 test accuracy:0.8480
# Epoch: 7 |Step: 100 |train loss:0.6350
# Epoch 7 |step  100 loss: 0.6350 test accuracy:0.8510
# Epoch: 7 |Step: 200 |train loss:0.2574
# Epoch 7 |step  200 loss: 0.2574 test accuracy:0.8537
# Epoch: 7 |Step: 300 |train loss:0.3134
# Epoch 7 |step  300 loss: 0.3134 test accuracy:0.8463
# Epoch: 7 |Step: 400 |train loss:0.4751
# Epoch 7 |step  400 loss: 0.4751 test accuracy:0.8491
# Epoch: 7 |Step: 500 |train loss:0.5456
# Epoch 7 |step  500 loss: 0.5456 test accuracy:0.8479
# Epoch: 7 |Step: 600 |train loss:0.5341
# Epoch 7 |step  600 loss: 0.5341 test accuracy:0.8502
# Epoch: 7 |Step: 700 |train loss:0.5605
# Epoch 7 |step  700 loss: 0.5605 test accuracy:0.8555
# Epoch: 7 |Step: 800 |train loss:0.3473
# Epoch 7 |step  800 loss: 0.3473 test accuracy:0.8467
# Epoch: 7 |Step: 900 |train loss:0.5253
# Epoch 7 |step  900 loss: 0.5253 test accuracy:0.8521
# Finished Training
# Epoch 7 |step  937 loss: 0.4546 test accuracy:0.8516
# Epoch: 8 |Step: 0 |train loss:0.6071
# Epoch 8 |step  0 loss: 0.6071 test accuracy:0.8494
# Epoch: 8 |Step: 100 |train loss:0.4387
# Epoch 8 |step  100 loss: 0.4387 test accuracy:0.8439
# Epoch: 8 |Step: 200 |train loss:0.2969
# Epoch 8 |step  200 loss: 0.2969 test accuracy:0.8541
# Epoch: 8 |Step: 300 |train loss:0.4061
# Epoch 8 |step  300 loss: 0.4061 test accuracy:0.8567
# Epoch: 8 |Step: 400 |train loss:0.4984
# Epoch 8 |step  400 loss: 0.4984 test accuracy:0.8622
# Epoch: 8 |Step: 500 |train loss:0.5713
# Epoch 8 |step  500 loss: 0.5713 test accuracy:0.8584
# Epoch: 8 |Step: 600 |train loss:0.6214
# Epoch 8 |step  600 loss: 0.6214 test accuracy:0.8559
# Epoch: 8 |Step: 700 |train loss:0.5015
# Epoch 8 |step  700 loss: 0.5015 test accuracy:0.8532
# Epoch: 8 |Step: 800 |train loss:0.5052
# Epoch 8 |step  800 loss: 0.5052 test accuracy:0.8574
# Epoch: 8 |Step: 900 |train loss:0.6011
# Epoch 8 |step  900 loss: 0.6011 test accuracy:0.8572
# Finished Training
# Epoch 8 |step  937 loss: 0.6497 test accuracy:0.8416
# Epoch: 9 |Step: 0 |train loss:0.4847
# Epoch 9 |step  0 loss: 0.4847 test accuracy:0.8460
# Epoch: 9 |Step: 100 |train loss:0.3082
# Epoch 9 |step  100 loss: 0.3082 test accuracy:0.8541
# Epoch: 9 |Step: 200 |train loss:0.6278
# Epoch 9 |step  200 loss: 0.6278 test accuracy:0.8554
# Epoch: 9 |Step: 300 |train loss:0.3502
# Epoch 9 |step  300 loss: 0.3502 test accuracy:0.8547
# Epoch: 9 |Step: 400 |train loss:0.4997
# Epoch 9 |step  400 loss: 0.4997 test accuracy:0.8500
# Epoch: 9 |Step: 500 |train loss:0.3291
# Epoch 9 |step  500 loss: 0.3291 test accuracy:0.8593
# Epoch: 9 |Step: 600 |train loss:0.5922
# Epoch 9 |step  600 loss: 0.5922 test accuracy:0.8595
# Epoch: 9 |Step: 700 |train loss:0.2852
# Epoch 9 |step  700 loss: 0.2852 test accuracy:0.8573
# Epoch: 9 |Step: 800 |train loss:0.5838
# Epoch 9 |step  800 loss: 0.5838 test accuracy:0.8519
# Epoch: 9 |Step: 900 |train loss:0.6672
# Epoch 9 |step  900 loss: 0.6672 test accuracy:0.8566
# Finished Training
# Epoch 9 |step  937 loss: 0.6321 test accuracy:0.8679
